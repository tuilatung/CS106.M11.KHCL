# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using {device} device')
# Out:
# Using cuda device

# %%
# !pip install colabgymrender==1.0.2
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !apt update && apt install xvfb
# Out:
# Collecting colabgymrender==1.0.2
#   Downloading colabgymrender-1.0.2.tar.gz (1.8 kB)
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-2.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (0.2.3.5)
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (0.17.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (4.1.2.30)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.19.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->colabgymrender==1.0.2) (0.16.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (4.4.2)
# Requirement already satisfied: imageio<3.0,>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (2.4.1)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (4.62.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.1.2->moviepy->colabgymrender==1.0.2) (7.1.2)
# Collecting EasyProcess
#   Downloading EasyProcess-0.3-py2.py3-none-any.whl (7.9 kB)
# Building wheels for collected packages: colabgymrender
#   Building wheel for colabgymrender (setup.py) ... done
#   Created wheel for colabgymrender: filename=colabgymrender-1.0.2-py3-none-any.whl size=2444 sha256=914425b5af79c6805c3464835627588ae6b8640d983442ea2d249c28a5f02bd8
#   Stored in directory: /root/.cache/pip/wheels/1f/56/73/3697080da5fc7b120516aef37d1d1eb2380515ba9e272b8ccd
# Successfully built colabgymrender
# Installing collected packages: EasyProcess, pyvirtualdisplay, colabgymrender
# Successfully installed EasyProcess-0.3 colabgymrender-1.0.2 pyvirtualdisplay-2.2
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [73.9 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:15 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [833 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,820 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,452 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,230 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [933 kB]
# Get:22 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,461 kB]
# Get:23 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [691 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,898 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [12.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [11.6 kB]
# Get:27 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.9 kB]
# Fetched 13.8 MB in 3s (4,122 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 79 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   xserver-common
# Recommended packages:
#   xfonts-base
# The following NEW packages will be installed:
#   xvfb
# The following packages will be upgraded:
#   xserver-common
# 1 upgraded, 1 newly installed, 0 to remove and 78 not upgraded.
# Need to get 811 kB of archives.
# After this operation, 2,272 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-common all 2:1.19.6-1ubuntu4.10 [26.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.10 [784 kB]
# Fetched 811 kB in 1s (709 kB/s)
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../xserver-common_2%3a1.19.6-1ubuntu4.10_all.deb ...
# Unpacking xserver-common (2:1.19.6-1ubuntu4.10) over (2:1.19.6-1ubuntu4.9) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.10_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.10) ...
# Setting up xserver-common (2:1.19.6-1ubuntu4.10) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.10) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
from colabgymrender.recorder import Recorder
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %%
env = gym.make('MountainCar-v0')
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0

while not done:
    action = env.action_space.sample()
    next_state, reward, done, info = env.step(action)
    total_reward += reward
    state = next_state

print(total_reward)
env.play()
# Out:
# -200.0
# 100%|█████████▉| 201/202 [00:00<00:00, 285.12it/s]
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
total_reward
# Out:
# -200.0

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, env):
        super(NeuralNetwork, self).__init__()
    
        self.network = nn.Sequential(
            nn.Linear(env.observation_space.shape[0], 64),
            nn.ReLU(),
            # nn.Tanh(),
            nn.Linear(64, env.action_space.n)
        )
    
    def forward(self, state):
        return self.network(state)
    
    def choose_action(self, state):
        state = torch.tensor(state, dtype=torch.float32)
        q_values = self(state.unsqueeze(0)) # pytorch requires inputs in terms of batch
        best_action = torch.argmax(q_values, dim=1)[0]

        return best_action.detach().item()

# %%
def fill_memory(env):
    memory = deque(maxlen=memory_size)
    state = env.reset()
    for _ in range(min_replay_size):
        action = env.action_space.sample()
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        state = next_state
        if done:
            env.reset()
    
    return memory

# %%
def dqn_training(env, max_num_steps, max_epsilon, min_epsilon, num_epsilon_decay_intervals, gamma, lr):
    q_net = NeuralNetwork(env)
    target_net = NeuralNetwork(env)
    target_net.load_state_dict(q_net.state_dict())
    optimizer = torch.optim.Adam(q_net.parameters(), lr=lr)

    memory = fill_memory(env)
    reward_buffer = deque(maxlen=100) # Rewards of the previous 100 episodes

    reward_per_episode = 0.0
    state = env.reset()
    all_rewards = []
    for step in range(max_num_steps):
        epsilon = np.interp(step, [0, num_epsilon_decay_intervals], [max_epsilon, min_epsilon])

        random_number = np.random.uniform(0,1)
        if random_number <= epsilon:
            action = env.action_space.sample()
        else:
            action = q_net.choose_action(state)
        
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        reward_per_episode += reward

        state = next_state

        if done:
            state = env.reset()
            reward_buffer.append(reward_per_episode)
            all_rewards.append((step, reward_per_episode))
            reward_per_episode = 0.0

        
        # Take a batch of experiences from the memory
        experiences = random.sample(memory, batch_size)
        states = [ex[0] for ex in experiences]
        actions = [ex[1] for ex in experiences]
        rewards = [ex[2] for ex in experiences]
        dones = [ex[3] for ex in experiences]
        next_states = [ex[4] for ex in experiences]

        states = torch.tensor(states, dtype=torch.float32)
        actions = torch.tensor(actions, dtype=torch.int64).unsqueeze(-1) # (batch_size,) --> (batch_size, 1)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(-1)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(-1)
        next_states = torch.tensor(next_states, dtype=torch.float32)

        # Compute targets using the formulation sample = r + gamma * max q(s',a')
        target_q_values = target_net(next_states)
        max_target_q_values = target_q_values.max(dim=1, keepdim=True)[0]
        targets = rewards + gamma * (1-dones) * max_target_q_values

        # Compute loss
        q_values = q_net(states)

        action_q_values = torch.gather(input=q_values, dim=1, index=actions)
        loss = torch.nn.functional.mse_loss(action_q_values, targets)

        # gradient descent for q-network
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # update target network
        if (step+1) % target_update_frequency == 0:
            target_net.load_state_dict(q_net.state_dict())

        # print training results
        if (step+1) % 1000 == 0:
            average_reward = np.mean(reward_buffer)
            print(f'Episode: {len(all_rewards)} Step: {step+1} Average reward: {average_reward}')

    return all_rewards, q_net

# %%
# """ This is baseline """

# # Hyperparameters
# max_epsilon = 1.0
# min_epsilon = 0.01
# max_num_steps = 50000
# epsilon_decay_intervals = 10000
# gamma = 0.99 # discount
# alpha = 5e-4 # learning rate

# memory_size = 50000
# min_replay_size = 1000
# batch_size = 32

# target_update_frequency = 1000 # target network update frequency

# %%
# Hyperparameters
max_epsilon = 1.0
min_epsilon = 0.01
max_num_steps = 200000
epsilon_decay_intervals = 10000
gamma = 0.99 # discount
alpha = 3e-3 # learning rate

memory_size = 100000
min_replay_size = 1000
batch_size = 128

target_update_frequency = 1000 # target network update frequency

# %%
all_rewards, q_net = dqn_training(env, max_num_steps, max_epsilon, min_epsilon, epsilon_decay_intervals, gamma, lr=alpha)
# Out:
# Episode: 5 Step: 1000 Average reward: -200.0
# Episode: 10 Step: 2000 Average reward: -200.0
# Episode: 15 Step: 3000 Average reward: -200.0
# Episode: 20 Step: 4000 Average reward: -200.0
# Episode: 25 Step: 5000 Average reward: -200.0
# Episode: 30 Step: 6000 Average reward: -200.0
# Episode: 35 Step: 7000 Average reward: -200.0
# Episode: 40 Step: 8000 Average reward: -200.0
# Episode: 45 Step: 9000 Average reward: -200.0
# Episode: 50 Step: 10000 Average reward: -200.0
# Episode: 55 Step: 11000 Average reward: -200.0
# Episode: 60 Step: 12000 Average reward: -200.0
# Episode: 65 Step: 13000 Average reward: -200.0
# Episode: 70 Step: 14000 Average reward: -200.0
# Episode: 75 Step: 15000 Average reward: -200.0
# Episode: 80 Step: 16000 Average reward: -200.0
# Episode: 85 Step: 17000 Average reward: -200.0
# Episode: 90 Step: 18000 Average reward: -199.67777777777778
# Episode: 95 Step: 19000 Average reward: -199.67368421052632
# Episode: 100 Step: 20000 Average reward: -199.26
# Episode: 105 Step: 21000 Average reward: -198.47
# Episode: 111 Step: 22000 Average reward: -197.09
# Episode: 116 Step: 23000 Average reward: -196.94
# Episode: 121 Step: 24000 Average reward: -196.48
# Episode: 127 Step: 25000 Average reward: -195.72
# Episode: 132 Step: 26000 Average reward: -194.26
# Episode: 138 Step: 27000 Average reward: -192.72
# Episode: 144 Step: 28000 Average reward: -191.33
# Episode: 150 Step: 29000 Average reward: -189.5
# Episode: 155 Step: 30000 Average reward: -188.85
# Episode: 160 Step: 31000 Average reward: -188.56
# Episode: 166 Step: 32000 Average reward: -186.75
# Episode: 172 Step: 33000 Average reward: -185.17
# Episode: 178 Step: 34000 Average reward: -182.87
# Episode: 184 Step: 35000 Average reward: -180.83
# Episode: 190 Step: 36000 Average reward: -179.59
# Episode: 196 Step: 37000 Average reward: -176.88
# Episode: 203 Step: 38000 Average reward: -175.45
# Episode: 209 Step: 39000 Average reward: -173.63
# Episode: 215 Step: 40000 Average reward: -171.47
# Episode: 221 Step: 41000 Average reward: -170.87
# Episode: 227 Step: 42000 Average reward: -169.92
# Episode: 233 Step: 43000 Average reward: -168.9
# Episode: 238 Step: 44000 Average reward: -169.44
# Episode: 244 Step: 45000 Average reward: -169.12
# Episode: 250 Step: 46000 Average reward: -169.72
# Episode: 257 Step: 47000 Average reward: -167.18
# Episode: 264 Step: 48000 Average reward: -164.24
# Episode: 271 Step: 49000 Average reward: -161.87
# Episode: 277 Step: 50000 Average reward: -161.34
# Episode: 283 Step: 51000 Average reward: -161.79
# Episode: 290 Step: 52000 Average reward: -159.92
# Episode: 296 Step: 53000 Average reward: -160.92
# Episode: 302 Step: 54000 Average reward: -160.42
# Episode: 309 Step: 55000 Average reward: -160.78
# Episode: 315 Step: 56000 Average reward: -160.32
# Episode: 321 Step: 57000 Average reward: -159.38
# Episode: 327 Step: 58000 Average reward: -158.46
# Episode: 333 Step: 59000 Average reward: -159.54
# Episode: 339 Step: 60000 Average reward: -158.8
# Episode: 346 Step: 61000 Average reward: -158.0
# Episode: 352 Step: 62000 Average reward: -157.54
# Episode: 358 Step: 63000 Average reward: -158.58
# Episode: 364 Step: 64000 Average reward: -159.94
# Episode: 370 Step: 65000 Average reward: -161.14
# Episode: 376 Step: 66000 Average reward: -161.49
# Episode: 382 Step: 67000 Average reward: -161.35
# Episode: 388 Step: 68000 Average reward: -163.17
# Episode: 394 Step: 69000 Average reward: -162.79
# Episode: 400 Step: 70000 Average reward: -162.94
# Episode: 407 Step: 71000 Average reward: -163.4
# Episode: 413 Step: 72000 Average reward: -163.83
# Episode: 419 Step: 73000 Average reward: -163.05
# Episode: 426 Step: 74000 Average reward: -162.53
# Episode: 432 Step: 75000 Average reward: -162.13
# Episode: 439 Step: 76000 Average reward: -160.78
# Episode: 446 Step: 77000 Average reward: -159.13
# Episode: 453 Step: 78000 Average reward: -157.37
# Episode: 460 Step: 79000 Average reward: -157.34
# Episode: 465 Step: 80000 Average reward: -157.22
# Episode: 472 Step: 81000 Average reward: -156.9
# Episode: 478 Step: 82000 Average reward: -157.17
# Episode: 484 Step: 83000 Average reward: -157.73
# Episode: 490 Step: 84000 Average reward: -157.55
# Episode: 495 Step: 85000 Average reward: -157.63
# Episode: 502 Step: 86000 Average reward: -157.84
# Episode: 508 Step: 87000 Average reward: -157.75
# Episode: 514 Step: 88000 Average reward: -158.82
# Episode: 520 Step: 89000 Average reward: -158.86
# Episode: 527 Step: 90000 Average reward: -157.45
# Episode: 534 Step: 91000 Average reward: -157.77
# Episode: 540 Step: 92000 Average reward: -159.31
# Episode: 546 Step: 93000 Average reward: -160.38
# Episode: 553 Step: 94000 Average reward: -159.92
# Episode: 560 Step: 95000 Average reward: -159.94
# Episode: 566 Step: 96000 Average reward: -158.89
# Episode: 573 Step: 97000 Average reward: -157.86
# Episode: 581 Step: 98000 Average reward: -154.73
# Episode: 588 Step: 99000 Average reward: -151.39
# Episode: 595 Step: 100000 Average reward: -150.35
# Episode: 602 Step: 101000 Average reward: -150.39
# Episode: 609 Step: 102000 Average reward: -148.38
# Episode: 615 Step: 103000 Average reward: -146.51
# Episode: 624 Step: 104000 Average reward: -145.28
# Episode: 631 Step: 105000 Average reward: -144.42
# Episode: 638 Step: 106000 Average reward: -142.07
# Episode: 645 Step: 107000 Average reward: -140.88
# Episode: 652 Step: 108000 Average reward: -141.96
# Episode: 658 Step: 109000 Average reward: -142.13
# Episode: 666 Step: 110000 Average reward: -140.95
# Episode: 673 Step: 111000 Average reward: -140.6
# Episode: 679 Step: 112000 Average reward: -141.16
# Episode: 685 Step: 113000 Average reward: -144.45
# Episode: 691 Step: 114000 Average reward: -147.04
# Episode: 699 Step: 115000 Average reward: -144.74
# Episode: 705 Step: 116000 Average reward: -143.7
# Episode: 712 Step: 117000 Average reward: -146.62
# Episode: 719 Step: 118000 Average reward: -146.2
# Episode: 726 Step: 119000 Average reward: -147.51
# Episode: 732 Step: 120000 Average reward: -148.77
# Episode: 739 Step: 121000 Average reward: -148.14
# Episode: 746 Step: 122000 Average reward: -148.91
# Episode: 753 Step: 123000 Average reward: -148.83
# Episode: 760 Step: 124000 Average reward: -148.39
# Episode: 767 Step: 125000 Average reward: -147.88
# Episode: 774 Step: 126000 Average reward: -147.82
# Episode: 781 Step: 127000 Average reward: -147.33
# Episode: 789 Step: 128000 Average reward: -144.09
# Episode: 796 Step: 129000 Average reward: -142.98
# Episode: 803 Step: 130000 Average reward: -143.32
# Episode: 812 Step: 131000 Average reward: -139.88
# Episode: 819 Step: 132000 Average reward: -140.02
# Episode: 826 Step: 133000 Average reward: -139.46
# Episode: 834 Step: 134000 Average reward: -138.28
# Episode: 842 Step: 135000 Average reward: -136.7
# Episode: 849 Step: 136000 Average reward: -135.94
# Episode: 857 Step: 137000 Average reward: -133.92
# Episode: 865 Step: 138000 Average reward: -131.84
# Episode: 874 Step: 139000 Average reward: -130.17
# Episode: 882 Step: 140000 Average reward: -128.02
# Episode: 891 Step: 141000 Average reward: -127.03
# Episode: 900 Step: 142000 Average reward: -124.97
# Episode: 909 Step: 143000 Average reward: -123.49
# Episode: 917 Step: 144000 Average reward: -122.81
# Episode: 926 Step: 145000 Average reward: -121.06
# Episode: 934 Step: 146000 Average reward: -119.09
# Episode: 943 Step: 147000 Average reward: -118.23
# Episode: 952 Step: 148000 Average reward: -115.26
# Episode: 961 Step: 149000 Average reward: -115.17
# Episode: 970 Step: 150000 Average reward: -114.98
# Episode: 976 Step: 151000 Average reward: -116.7
# Episode: 985 Step: 152000 Average reward: -116.59
# Episode: 992 Step: 153000 Average reward: -118.87
# Episode: 999 Step: 154000 Average reward: -121.11
# Episode: 1006 Step: 155000 Average reward: -123.47
# Episode: 1014 Step: 156000 Average reward: -123.62
# Episode: 1022 Step: 157000 Average reward: -124.01
# Episode: 1030 Step: 158000 Average reward: -124.56
# Episode: 1037 Step: 159000 Average reward: -126.71
# Episode: 1046 Step: 160000 Average reward: -127.33
# Episode: 1054 Step: 161000 Average reward: -128.82
# Episode: 1061 Step: 162000 Average reward: -130.51
# Episode: 1069 Step: 163000 Average reward: -131.33
# Episode: 1077 Step: 164000 Average reward: -128.65
# Episode: 1087 Step: 165000 Average reward: -128.23
# Episode: 1094 Step: 166000 Average reward: -127.42
# Episode: 1102 Step: 167000 Average reward: -126.02
# Episode: 1109 Step: 168000 Average reward: -124.73
# Episode: 1118 Step: 169000 Average reward: -124.48
# Episode: 1125 Step: 170000 Average reward: -127.03
# Episode: 1132 Step: 171000 Average reward: -126.88
# Episode: 1139 Step: 172000 Average reward: -127.47
# Episode: 1147 Step: 173000 Average reward: -128.45
# Episode: 1154 Step: 174000 Average reward: -129.92
# Episode: 1162 Step: 175000 Average reward: -128.85
# Episode: 1169 Step: 176000 Average reward: -129.17
# Episode: 1177 Step: 177000 Average reward: -130.32
# Episode: 1185 Step: 178000 Average reward: -132.51
# Episode: 1192 Step: 179000 Average reward: -133.19
# Episode: 1202 Step: 180000 Average reward: -129.8
# Episode: 1209 Step: 181000 Average reward: -130.92
# Episode: 1217 Step: 182000 Average reward: -131.42
# Episode: 1224 Step: 183000 Average reward: -131.47
# Episode: 1232 Step: 184000 Average reward: -129.51
# Episode: 1239 Step: 185000 Average reward: -129.41
# Episode: 1248 Step: 186000 Average reward: -128.64
# Episode: 1255 Step: 187000 Average reward: -127.88
# Episode: 1262 Step: 188000 Average reward: -129.5
# Episode: 1269 Step: 189000 Average reward: -130.45
# Episode: 1278 Step: 190000 Average reward: -128.51
# Episode: 1286 Step: 191000 Average reward: -127.96
# Episode: 1294 Step: 192000 Average reward: -128.68
# Episode: 1302 Step: 193000 Average reward: -130.19
# Episode: 1310 Step: 194000 Average reward: -129.02
# Episode: 1317 Step: 195000 Average reward: -129.34
# Episode: 1326 Step: 196000 Average reward: -127.54
# Episode: 1335 Step: 197000 Average reward: -126.25
# Episode: 1343 Step: 198000 Average reward: -125.89
# Episode: 1353 Step: 199000 Average reward: -123.5
# Episode: 1361 Step: 200000 Average reward: -121.85

# %%
all_rewards = np.array(all_rewards)
plt.xlabel('Steps')
plt.ylabel('Score')
plt.plot(all_rewards[:, 0], all_rewards[:, 1])

# %%
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0
q_net.eval()

with torch.no_grad():
    while not done:
        #action = env.action_space.sample()
        action = q_net.choose_action(state)
        next_state, reward, done, info = env.step(action)
        total_reward += reward
        state = next_state

print(total_reward)
env.play()
# Out:
# -111.0
# 100%|██████████| 112/112 [00:00<00:00, 291.33it/s]
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
