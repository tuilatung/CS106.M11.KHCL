# %% [markdown]
# Họ và tên: Huỳnh Thiện Tùng
#
# MSSV: 19522492
#
# LAB06

# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using {device} device')
# Out:
# Using cuda device

# %%
# !pip install colabgymrender==1.0.2
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !apt update && apt install xvfb
# Out:
# Requirement already satisfied: colabgymrender==1.0.2 in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (0.17.3)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (2.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (4.1.2.30)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (0.2.3.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.3.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->colabgymrender==1.0.2) (0.16.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (4.4.2)
# Requirement already satisfied: imageio<3.0,>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (2.4.1)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (4.62.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.1.2->moviepy->colabgymrender==1.0.2) (7.1.2)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.7/dist-packages (from pyvirtualdisplay->colabgymrender==1.0.2) (0.3)
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Fetched 252 kB in 3s (87.3 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 78 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# xvfb is already the newest version (2:1.19.6-1ubuntu4.10).
# 0 upgraded, 0 newly installed, 0 to remove and 78 not upgraded.

# %%
from colabgymrender.recorder import Recorder

# %%
env = gym.make('MountainCar-v0')
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0

while not done:
    action = env.action_space.sample()
    next_state, reward, done, info = env.step(action)
    total_reward += reward
    state = next_state

print(total_reward)
env.play()
# Out:
# -200.0
# 100%|█████████▉| 201/202 [00:00<00:00, 265.80it/s]
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
total_reward
# Out:
# -200.0

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, env):
        super(NeuralNetwork, self).__init__()
    
        self.network = nn.Sequential(
            nn.Linear(env.observation_space.shape[0], 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.Sigmoid(),
            nn.Linear(128, env.action_space.n)
        )
    
    def forward(self, state):
        return self.network(state)
    
    def choose_action(self, state):
        state = torch.tensor(state, dtype=torch.float32)
        q_values = self(state.unsqueeze(0)) # pytorch requires inputs in terms of batch
        best_action = torch.argmax(q_values, dim=1)[0]

        return best_action.detach().item()

# %%
def fill_memory(env):
    memory = deque(maxlen=memory_size)
    state = env.reset()
    for _ in range(min_replay_size):
        action = env.action_space.sample()
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        state = next_state
        if done:
            env.reset()
    
    return memory

# %%
def dqn_training(env, max_num_steps, max_epsilon, min_epsilon, num_epsilon_decay_intervals, gamma, lr):
    q_net = NeuralNetwork(env)
    target_net = NeuralNetwork(env)
    target_net.load_state_dict(q_net.state_dict())
    optimizer = torch.optim.Adam(q_net.parameters(), lr=lr)

    memory = fill_memory(env)
    reward_buffer = deque(maxlen=100) # Rewards of the previous 100 episodes

    reward_per_episode = 0.0
    state = env.reset()
    all_rewards = []
    for step in range(max_num_steps):
        epsilon = np.interp(step, [0, num_epsilon_decay_intervals], [max_epsilon, min_epsilon])

        random_number = np.random.uniform(0,1)
        if random_number <= epsilon:
            action = env.action_space.sample()
        else:
            action = q_net.choose_action(state)
        
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        reward_per_episode += reward

        state = next_state

        if done:
            state = env.reset()
            reward_buffer.append(reward_per_episode)
            all_rewards.append((step, reward_per_episode))
            reward_per_episode = 0.0

        
        # Take a batch of experiences from the memory
        experiences = random.sample(memory, batch_size)
        states = [ex[0] for ex in experiences]
        actions = [ex[1] for ex in experiences]
        rewards = [ex[2] for ex in experiences]
        dones = [ex[3] for ex in experiences]
        next_states = [ex[4] for ex in experiences]

        states = torch.tensor(states, dtype=torch.float32)
        actions = torch.tensor(actions, dtype=torch.int64).unsqueeze(-1) # (batch_size,) --> (batch_size, 1)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(-1)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(-1)
        next_states = torch.tensor(next_states, dtype=torch.float32)

        # Compute targets using the formulation sample = r + gamma * max q(s',a')
        target_q_values = target_net(next_states)
        max_target_q_values = target_q_values.max(dim=1, keepdim=True)[0]
        targets = rewards + gamma * (1-dones) * max_target_q_values

        # Compute loss
        q_values = q_net(states)

        action_q_values = torch.gather(input=q_values, dim=1, index=actions)
        loss = torch.nn.functional.mse_loss(action_q_values, targets)

        # gradient descent for q-network
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # update target network
        if (step+1) % target_update_frequency == 0:
            target_net.load_state_dict(q_net.state_dict())

        # print training results
        if (step+1) % 1000 == 0:
            average_reward = np.mean(reward_buffer)
            print(f'Episode: {len(all_rewards)} Step: {step+1} Average reward: {average_reward}')

    return all_rewards, q_net

# %%
# """ This is baseline """

# # Hyperparameters
# max_epsilon = 1.0
# min_epsilon = 0.01
# max_num_steps = 50000
# epsilon_decay_intervals = 10000
# gamma = 0.99 # discount
# alpha = 5e-4 # learning rate

# memory_size = 50000
# min_replay_size = 1000
# batch_size = 32

# target_update_frequency = 1000 # target network update frequency

# %%
# Hyperparameters
max_epsilon = 1.0
min_epsilon = 0.001
max_num_steps = 150000
epsilon_decay_intervals = 10000
gamma = 0.99 # discount
alpha = 7e-4 # learning rate

memory_size = 100000
min_replay_size = 1000
batch_size = 256

target_update_frequency = 1000 # target network update frequency

# %%
all_rewards, q_net = dqn_training(env, max_num_steps, max_epsilon, min_epsilon, epsilon_decay_intervals, gamma, lr=alpha)
# Out:
# Episode: 5 Step: 1000 Average reward: -200.0
# Episode: 10 Step: 2000 Average reward: -200.0
# Episode: 15 Step: 3000 Average reward: -200.0
# Episode: 20 Step: 4000 Average reward: -200.0
# Episode: 25 Step: 5000 Average reward: -200.0
# Episode: 30 Step: 6000 Average reward: -200.0
# Episode: 35 Step: 7000 Average reward: -200.0
# Episode: 40 Step: 8000 Average reward: -200.0
# Episode: 45 Step: 9000 Average reward: -198.7111111111111
# Episode: 50 Step: 10000 Average reward: -196.34
# Episode: 56 Step: 11000 Average reward: -194.73214285714286
# Episode: 62 Step: 12000 Average reward: -191.90322580645162
# Episode: 68 Step: 13000 Average reward: -189.52941176470588
# Episode: 74 Step: 14000 Average reward: -189.14864864864865
# Episode: 79 Step: 15000 Average reward: -187.59493670886076
# Episode: 85 Step: 16000 Average reward: -187.91764705882352
# Episode: 91 Step: 17000 Average reward: -186.7032967032967
# Episode: 97 Step: 18000 Average reward: -185.0721649484536
# Episode: 102 Step: 19000 Average reward: -184.37
# Episode: 108 Step: 20000 Average reward: -183.29
# Episode: 113 Step: 21000 Average reward: -182.54
# Episode: 119 Step: 22000 Average reward: -181.38
# Episode: 125 Step: 23000 Average reward: -179.95
# Episode: 130 Step: 24000 Average reward: -179.49
# Episode: 135 Step: 25000 Average reward: -179.05
# Episode: 140 Step: 26000 Average reward: -178.86
# Episode: 145 Step: 27000 Average reward: -179.29
# Episode: 151 Step: 28000 Average reward: -179.53
# Episode: 156 Step: 29000 Average reward: -179.8
# Episode: 161 Step: 30000 Average reward: -180.39
# Episode: 167 Step: 31000 Average reward: -182.12
# Episode: 173 Step: 32000 Average reward: -181.13
# Episode: 179 Step: 33000 Average reward: -181.54
# Episode: 184 Step: 34000 Average reward: -181.84
# Episode: 189 Step: 35000 Average reward: -182.89
# Episode: 194 Step: 36000 Average reward: -183.8
# Episode: 199 Step: 37000 Average reward: -185.5
# Episode: 204 Step: 38000 Average reward: -186.08
# Episode: 209 Step: 39000 Average reward: -186.85
# Episode: 215 Step: 40000 Average reward: -187.34
# Episode: 220 Step: 41000 Average reward: -188.09
# Episode: 226 Step: 42000 Average reward: -188.05
# Episode: 231 Step: 43000 Average reward: -188.31
# Episode: 677 Step: 109000 Average reward: -134.52
# Episode: 686 Step: 110000 Average reward: -132.67
# Episode: 695 Step: 111000 Average reward: -131.93
# Episode: 702 Step: 112000 Average reward: -130.31
# Episode: 710 Step: 113000 Average reward: -130.69
# Episode: 719 Step: 114000 Average reward: -127.64
# Episode: 727 Step: 115000 Average reward: -128.15
# Episode: 733 Step: 116000 Average reward: -128.26
# Episode: 741 Step: 117000 Average reward: -126.85
# Episode: 750 Step: 118000 Average reward: -127.13
# Episode: 758 Step: 119000 Average reward: -125.85
# Episode: 766 Step: 120000 Average reward: -124.57
# Episode: 775 Step: 121000 Average reward: -123.44
# Episode: 784 Step: 122000 Average reward: -122.93
# Episode: 793 Step: 123000 Average reward: -123.04
# Episode: 802 Step: 124000 Average reward: -120.85
# Episode: 810 Step: 125000 Average reward: -119.73
# Episode: 819 Step: 126000 Average reward: -120.02
# Episode: 828 Step: 127000 Average reward: -117.83
# Episode: 836 Step: 128000 Average reward: -116.18
# Episode: 846 Step: 129000 Average reward: -114.67
# Episode: 855 Step: 130000 Average reward: -114.19
# Episode: 864 Step: 131000 Average reward: -112.73
# Episode: 873 Step: 132000 Average reward: -112.06
# Episode: 882 Step: 133000 Average reward: -111.63
# Episode: 892 Step: 134000 Average reward: -110.71
# Episode: 901 Step: 135000 Average reward: -110.43
# Episode: 910 Step: 136000 Average reward: -109.75
# Episode: 920 Step: 137000 Average reward: -108.74
# Episode: 930 Step: 138000 Average reward: -107.34
# Episode: 939 Step: 139000 Average reward: -106.72
# Episode: 949 Step: 140000 Average reward: -106.79
# Episode: 958 Step: 141000 Average reward: -106.52
# Episode: 968 Step: 142000 Average reward: -106.26
# Episode: 978 Step: 143000 Average reward: -105.25
# Episode: 987 Step: 144000 Average reward: -104.76
# Episode: 997 Step: 145000 Average reward: -104.58
# Episode: 1007 Step: 146000 Average reward: -103.49
# Episode: 1017 Step: 147000 Average reward: -102.86
# Episode: 1027 Step: 148000 Average reward: -103.11
# Episode: 1037 Step: 149000 Average reward: -102.96
# Episode: 1046 Step: 150000 Average reward: -102.55

# %%
all_rewards = np.array(all_rewards)
plt.xlabel('Steps')
plt.ylabel('Score')
plt.plot(all_rewards[:, 0], all_rewards[:, 1])

# %%
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0
q_net.eval()

with torch.no_grad():
    while not done:
        #action = env.action_space.sample()
        action = q_net.choose_action(state)
        next_state, reward, done, info = env.step(action)
        total_reward += reward
        state = next_state

print(total_reward)
env.play()
# Out:
# -83.0
#  99%|█████████▉| 84/85 [00:00<00:00, 289.48it/s]
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# # Nhận xét
#
# Trong quá trình thực nghiệm nhiều lần, em có một số báo cáo như sau:
#
# *   Giảm min epsilon còn **0.001**
# *   Tăng learning_rate lên **7e-4**
# *   Tăng số lượng vòng lặp lên **150000**
# *   Tăng batch size lên **128**
# *   Tăng memory size lên **100000**
# *   Thay đổi activation function: **nn.ReLU()**
# *   Thay đổi kiến trúc mạng Neural: thêm **Linear layer** với input shape = (128,128), thêm activation function **nn.Sigmoid()**
#
# Kết quả cuối cùng thì thuật toán cũng giúp giải được bài toán này nhưng điểm số chưa cao lắm với **85** nhịp, **-83** reward. Video dài **2** giây
