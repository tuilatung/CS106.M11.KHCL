# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using {device} device')
# Out:
# Using cuda device

# %%
# !pip install colabgymrender==1.0.2
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !apt update && apt install xvfb
# Out:
# Collecting colabgymrender==1.0.2
#   Downloading colabgymrender-1.0.2.tar.gz (1.8 kB)
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-2.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (0.2.3.5)
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (0.17.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (4.1.2.30)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.3.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->colabgymrender==1.0.2) (0.16.0)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (4.62.3)
# Requirement already satisfied: imageio<3.0,>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (2.4.1)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (4.4.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.1.2->moviepy->colabgymrender==1.0.2) (7.1.2)
# Collecting EasyProcess
#   Downloading EasyProcess-0.3-py2.py3-none-any.whl (7.9 kB)
# Building wheels for collected packages: colabgymrender
#   Building wheel for colabgymrender (setup.py) ... done
#   Created wheel for colabgymrender: filename=colabgymrender-1.0.2-py3-none-any.whl size=2444 sha256=01842568d121899594cb809a772332e439209acfdbc3014df9d4dbcfd1ae69a6
#   Stored in directory: /root/.cache/pip/wheels/1f/56/73/3697080da5fc7b120516aef37d1d1eb2380515ba9e272b8ccd
# Successfully built colabgymrender
# Installing collected packages: EasyProcess, pyvirtualdisplay, colabgymrender
# Successfully installed EasyProcess-0.3 colabgymrender-1.0.2 pyvirtualdisplay-2.2
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:2 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [73.9 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:17 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,820 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,452 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,230 kB]
# Get:20 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [933 kB]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,461 kB]
# Get:22 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [691 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,898 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [11.6 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [12.6 kB]
# Get:26 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.9 kB]
# Fetched 12.9 MB in 3s (3,932 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 76 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   xserver-common
# Recommended packages:
#   xfonts-base
# The following NEW packages will be installed:
#   xvfb
# The following packages will be upgraded:
#   xserver-common
# 1 upgraded, 1 newly installed, 0 to remove and 75 not upgraded.
# Need to get 811 kB of archives.
# After this operation, 2,272 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-common all 2:1.19.6-1ubuntu4.10 [26.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.10 [784 kB]
# Fetched 811 kB in 1s (865 kB/s)
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../xserver-common_2%3a1.19.6-1ubuntu4.10_all.deb ...
# Unpacking xserver-common (2:1.19.6-1ubuntu4.10) over (2:1.19.6-1ubuntu4.9) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.10_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.10) ...
# Setting up xserver-common (2:1.19.6-1ubuntu4.10) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.10) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
from colabgymrender.recorder import Recorder
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %%
env = gym.make('MountainCar-v0')
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0

while not done:
    action = env.action_space.sample()
    next_state, reward, done, info = env.step(action)
    total_reward += reward
    state = next_state

print(total_reward)
env.play()
# Out:
# -200.0
# 100%|█████████▉| 201/202 [00:00<00:00, 293.44it/s]
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
total_reward
# Out:
# -200.0

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, env):
        super(NeuralNetwork, self).__init__()
    
        self.network = nn.Sequential(
            nn.Linear(env.observation_space.shape[0], 64),
            nn.ReLU(),
            # nn.Tanh(),
            nn.Linear(64, env.action_space.n)
        )
    
    def forward(self, state):
        return self.network(state)
    
    def choose_action(self, state):
        state = torch.tensor(state, dtype=torch.float32)
        q_values = self(state.unsqueeze(0)) # pytorch requires inputs in terms of batch
        best_action = torch.argmax(q_values, dim=1)[0]

        return best_action.detach().item()

# %%
def fill_memory(env):
    memory = deque(maxlen=memory_size)
    state = env.reset()
    for _ in range(min_replay_size):
        action = env.action_space.sample()
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        state = next_state
        if done:
            env.reset()
    
    return memory

# %%
def dqn_training(env, max_num_steps, max_epsilon, min_epsilon, num_epsilon_decay_intervals, gamma, lr):
    q_net = NeuralNetwork(env)
    target_net = NeuralNetwork(env)
    target_net.load_state_dict(q_net.state_dict())
    optimizer = torch.optim.Adam(q_net.parameters(), lr=lr)

    memory = fill_memory(env)
    reward_buffer = deque(maxlen=100) # Rewards of the previous 100 episodes

    reward_per_episode = 0.0
    state = env.reset()
    all_rewards = []
    for step in range(max_num_steps):
        epsilon = np.interp(step, [0, num_epsilon_decay_intervals], [max_epsilon, min_epsilon])

        random_number = np.random.uniform(0,1)
        if random_number <= epsilon:
            action = env.action_space.sample()
        else:
            action = q_net.choose_action(state)
        
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        reward_per_episode += reward

        state = next_state

        if done:
            state = env.reset()
            reward_buffer.append(reward_per_episode)
            all_rewards.append((step, reward_per_episode))
            reward_per_episode = 0.0

        
        # Take a batch of experiences from the memory
        experiences = random.sample(memory, batch_size)
        states = [ex[0] for ex in experiences]
        actions = [ex[1] for ex in experiences]
        rewards = [ex[2] for ex in experiences]
        dones = [ex[3] for ex in experiences]
        next_states = [ex[4] for ex in experiences]

        states = torch.tensor(states, dtype=torch.float32)
        actions = torch.tensor(actions, dtype=torch.int64).unsqueeze(-1) # (batch_size,) --> (batch_size, 1)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(-1)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(-1)
        next_states = torch.tensor(next_states, dtype=torch.float32)

        # Compute targets using the formulation sample = r + gamma * max q(s',a')
        target_q_values = target_net(next_states)
        max_target_q_values = target_q_values.max(dim=1, keepdim=True)[0]
        targets = rewards + gamma * (1-dones) * max_target_q_values

        # Compute loss
        q_values = q_net(states)

        action_q_values = torch.gather(input=q_values, dim=1, index=actions)
        loss = torch.nn.functional.mse_loss(action_q_values, targets)

        # gradient descent for q-network
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # update target network
        if (step+1) % target_update_frequency == 0:
            target_net.load_state_dict(q_net.state_dict())

        # print training results
        if (step+1) % 1000 == 0:
            average_reward = np.mean(reward_buffer)
            print(f'Episode: {len(all_rewards)} Step: {step+1} Average reward: {average_reward}')

    return all_rewards, q_net

# %%
""" This is baseline """

# Hyperparameters
max_epsilon = 1.0
min_epsilon = 0.01
max_num_steps = 50000
epsilon_decay_intervals = 10000
gamma = 0.99 # discount
alpha = 5e-4 # learning rate

memory_size = 50000
min_replay_size = 1000
batch_size = 32

target_update_frequency = 1000 # target network update frequency

# %%
# Hyperparameters
max_epsilon = 1.0
min_epsilon = 0.01
max_num_steps = 100000
epsilon_decay_intervals = 10000
gamma = 0.99 # discount
alpha = 1e-3 # learning rate

memory_size = 100000
min_replay_size = 1000
batch_size = 128

target_update_frequency = 1000 # target network update frequency

# %%
all_rewards, q_net = dqn_training(env, max_num_steps, max_epsilon, min_epsilon, epsilon_decay_intervals, gamma, lr=alpha)
# Out:
# Episode: 5 Step: 1000 Average reward: -200.0
# Episode: 10 Step: 2000 Average reward: -200.0
# Episode: 15 Step: 3000 Average reward: -200.0
# Episode: 20 Step: 4000 Average reward: -200.0
# Episode: 25 Step: 5000 Average reward: -200.0
# Episode: 30 Step: 6000 Average reward: -200.0
# Episode: 35 Step: 7000 Average reward: -200.0
# Episode: 40 Step: 8000 Average reward: -200.0
# Episode: 45 Step: 9000 Average reward: -200.0
# Episode: 50 Step: 10000 Average reward: -200.0
# Episode: 55 Step: 11000 Average reward: -200.0
# Episode: 60 Step: 12000 Average reward: -199.75
# Episode: 65 Step: 13000 Average reward: -199.76923076923077
# Episode: 70 Step: 14000 Average reward: -199.78571428571428
# Episode: 75 Step: 15000 Average reward: -199.8
# Episode: 80 Step: 16000 Average reward: -199.8125
# Episode: 85 Step: 17000 Average reward: -199.25882352941176
# Episode: 90 Step: 18000 Average reward: -199.25555555555556
# Episode: 95 Step: 19000 Average reward: -198.65263157894736
# Episode: 100 Step: 20000 Average reward: -198.27
# Episode: 106 Step: 21000 Average reward: -196.62
# Episode: 111 Step: 22000 Average reward: -196.37
# Episode: 117 Step: 23000 Average reward: -195.33
# Episode: 122 Step: 24000 Average reward: -195.33
# Episode: 127 Step: 25000 Average reward: -195.17
# Episode: 132 Step: 26000 Average reward: -194.71
# Episode: 137 Step: 27000 Average reward: -194.27
# Episode: 143 Step: 28000 Average reward: -193.94
# Episode: 148 Step: 29000 Average reward: -193.15
# Episode: 153 Step: 30000 Average reward: -192.7
# Episode: 159 Step: 31000 Average reward: -191.92
# Episode: 164 Step: 32000 Average reward: -191.92
# Episode: 169 Step: 33000 Average reward: -191.65
# Episode: 174 Step: 34000 Average reward: -190.54
# Episode: 179 Step: 35000 Average reward: -190.54
# Episode: 185 Step: 36000 Average reward: -190.47
# Episode: 190 Step: 37000 Average reward: -190.39
# Episode: 195 Step: 38000 Average reward: -190.77
# Episode: 200 Step: 39000 Average reward: -191.13
# Episode: 205 Step: 40000 Average reward: -192.19
# Episode: 210 Step: 41000 Average reward: -192.25
# Episode: 215 Step: 42000 Average reward: -193.29
# Episode: 220 Step: 43000 Average reward: -193.21
# Episode: 225 Step: 44000 Average reward: -193.37
# Episode: 231 Step: 45000 Average reward: -192.48
# Episode: 236 Step: 46000 Average reward: -191.65
# Episode: 241 Step: 47000 Average reward: -192.04
# Episode: 248 Step: 48000 Average reward: -190.09
# Episode: 253 Step: 49000 Average reward: -190.05
# Episode: 258 Step: 50000 Average reward: -190.25
# Episode: 264 Step: 51000 Average reward: -189.4
# Episode: 270 Step: 52000 Average reward: -187.51
# Episode: 275 Step: 53000 Average reward: -188.13
# Episode: 281 Step: 54000 Average reward: -186.49
# Episode: 287 Step: 55000 Average reward: -185.89
# Episode: 292 Step: 56000 Average reward: -184.43
# Episode: 298 Step: 57000 Average reward: -182.63
# Episode: 305 Step: 58000 Average reward: -180.74
# Episode: 310 Step: 59000 Average reward: -179.82
# Episode: 317 Step: 60000 Average reward: -176.74
# Episode: 323 Step: 61000 Average reward: -174.44
# Episode: 330 Step: 62000 Average reward: -172.17
# Episode: 336 Step: 63000 Average reward: -171.61
# Episode: 341 Step: 64000 Average reward: -170.16
# Episode: 347 Step: 65000 Average reward: -170.99
# Episode: 353 Step: 66000 Average reward: -170.42
# Episode: 359 Step: 67000 Average reward: -169.81
# Episode: 365 Step: 68000 Average reward: -168.23
# Episode: 371 Step: 69000 Average reward: -168.71
# Episode: 378 Step: 70000 Average reward: -165.68
# Episode: 384 Step: 71000 Average reward: -164.9
# Episode: 390 Step: 72000 Average reward: -163.62
# Episode: 397 Step: 73000 Average reward: -162.42
# Episode: 404 Step: 74000 Average reward: -160.56
# Episode: 410 Step: 75000 Average reward: -160.13
# Episode: 417 Step: 76000 Average reward: -159.69
# Episode: 424 Step: 77000 Average reward: -159.23
# Episode: 430 Step: 78000 Average reward: -158.72
# Episode: 437 Step: 79000 Average reward: -158.1
# Episode: 443 Step: 80000 Average reward: -157.06
# Episode: 450 Step: 81000 Average reward: -155.58
# Episode: 456 Step: 82000 Average reward: -154.2
# Episode: 462 Step: 83000 Average reward: -154.37
# Episode: 469 Step: 84000 Average reward: -153.63
# Episode: 476 Step: 85000 Average reward: -152.51
# Episode: 482 Step: 86000 Average reward: -152.43
# Episode: 489 Step: 87000 Average reward: -152.43
# Episode: 495 Step: 88000 Average reward: -152.98
# Episode: 501 Step: 89000 Average reward: -154.49
# Episode: 508 Step: 90000 Average reward: -154.37
# Episode: 514 Step: 91000 Average reward: -154.81
# Episode: 520 Step: 92000 Average reward: -155.47
# Episode: 526 Step: 93000 Average reward: -156.31
# Episode: 532 Step: 94000 Average reward: -157.62
# Episode: 537 Step: 95000 Average reward: -158.41
# Episode: 544 Step: 96000 Average reward: -158.95
# Episode: 550 Step: 97000 Average reward: -160.15
# Episode: 556 Step: 98000 Average reward: -161.13
# Episode: 562 Step: 99000 Average reward: -160.17
# Episode: 568 Step: 100000 Average reward: -161.27

# %%
all_rewards = np.array(all_rewards)
plt.xlabel('Steps')
plt.ylabel('Score')
plt.plot(all_rewards[:, 0], all_rewards[:, 1])

# %%
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0
q_net.eval()

with torch.no_grad():
    while not done:
        #action = env.action_space.sample()
        action = q_net.choose_action(state)
        next_state, reward, done, info = env.step(action)
        total_reward += reward
        state = next_state

print(total_reward)
env.play()
# Out:
# -170.0
#  99%|█████████▉| 171/172 [00:00<00:00, 288.45it/s]
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
