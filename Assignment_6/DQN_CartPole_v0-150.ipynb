# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using {device} device')
# Out:
# Using cuda device

# %%
# !pip install colabgymrender==1.0.2
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !apt update && apt install xvfb
# Out:
# Requirement already satisfied: colabgymrender==1.0.2 in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (4.1.2.30)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (2.2)
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (0.17.3)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.7/dist-packages (from colabgymrender==1.0.2) (0.2.3.5)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.19.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym->colabgymrender==1.0.2) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->colabgymrender==1.0.2) (0.16.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (4.62.3)
# Requirement already satisfied: imageio<3.0,>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender==1.0.2) (2.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.1.2->moviepy->colabgymrender==1.0.2) (7.1.2)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.7/dist-packages (from pyvirtualdisplay->colabgymrender==1.0.2) (0.3)
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:7 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Fetched 167 kB in 5s (36.1 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 78 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# xvfb is already the newest version (2:1.19.6-1ubuntu4.10).
# 0 upgraded, 0 newly installed, 0 to remove and 78 not upgraded.

# %%
from colabgymrender.recorder import Recorder

# %%
env = gym.make('MountainCar-v0')
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0

while not done:
    action = env.action_space.sample()
    next_state, reward, done, info = env.step(action)
    total_reward += reward
    state = next_state

print(total_reward)
env.play()
# Out:
# -200.0
# 100%|█████████▉| 201/202 [00:00<00:00, 322.81it/s]
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
total_reward
# Out:
# -200.0

# %%
from torch.nn.modules.activation import Tanh
class NeuralNetwork(nn.Module):
    def __init__(self, env):
        super(NeuralNetwork, self).__init__()
    
        self.network = nn.Sequential(
            nn.Linear(env.observation_space.shape[0], 64),
            nn.ReLU(),
            # nn.Tanh(),
            nn.Linear(64, env.action_space.n)
        )
    
    def forward(self, state):
        return self.network(state)
    
    def choose_action(self, state):
        state = torch.tensor(state, dtype=torch.float32)
        q_values = self(state.unsqueeze(0)) # pytorch requires inputs in terms of batch
        best_action = torch.argmax(q_values, dim=1)[0]

        return best_action.detach().item()

# %%
def fill_memory(env):
    memory = deque(maxlen=memory_size)
    state = env.reset()
    for _ in range(min_replay_size):
        action = env.action_space.sample()
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        state = next_state
        if done:
            env.reset()
    
    return memory

# %%
def dqn_training(env, max_num_steps, max_epsilon, min_epsilon, num_epsilon_decay_intervals, gamma, lr):
    q_net = NeuralNetwork(env)
    target_net = NeuralNetwork(env)
    target_net.load_state_dict(q_net.state_dict())
    optimizer = torch.optim.Adam(q_net.parameters(), lr=lr)

    memory = fill_memory(env)
    reward_buffer = deque(maxlen=100) # Rewards of the previous 100 episodes

    reward_per_episode = 0.0
    state = env.reset()
    all_rewards = []
    for step in range(max_num_steps):
        epsilon = np.interp(step, [0, num_epsilon_decay_intervals], [max_epsilon, min_epsilon])

        random_number = np.random.uniform(0,1)
        if random_number <= epsilon:
            action = env.action_space.sample()
        else:
            action = q_net.choose_action(state)
        
        next_state, reward, done, info = env.step(action)
        experience = (state, action, reward, done, next_state)
        memory.append(experience)
        reward_per_episode += reward

        state = next_state

        if done:
            state = env.reset()
            reward_buffer.append(reward_per_episode)
            all_rewards.append((step, reward_per_episode))
            reward_per_episode = 0.0

        
        # Take a batch of experiences from the memory
        experiences = random.sample(memory, batch_size)
        states = [ex[0] for ex in experiences]
        actions = [ex[1] for ex in experiences]
        rewards = [ex[2] for ex in experiences]
        dones = [ex[3] for ex in experiences]
        next_states = [ex[4] for ex in experiences]

        states = torch.tensor(states, dtype=torch.float32)
        actions = torch.tensor(actions, dtype=torch.int64).unsqueeze(-1) # (batch_size,) --> (batch_size, 1)
        rewards = torch.tensor(rewards, dtype=torch.float32).unsqueeze(-1)
        dones = torch.tensor(dones, dtype=torch.float32).unsqueeze(-1)
        next_states = torch.tensor(next_states, dtype=torch.float32)

        # Compute targets using the formulation sample = r + gamma * max q(s',a')
        target_q_values = target_net(next_states)
        max_target_q_values = target_q_values.max(dim=1, keepdim=True)[0]
        targets = rewards + gamma * (1-dones) * max_target_q_values

        # Compute loss
        q_values = q_net(states)

        action_q_values = torch.gather(input=q_values, dim=1, index=actions)
        loss = torch.nn.functional.mse_loss(action_q_values, targets)

        # gradient descent for q-network
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # update target network
        if (step+1) % target_update_frequency == 0:
            target_net.load_state_dict(q_net.state_dict())

        # print training results
        if (step+1) % 1000 == 0:
            average_reward = np.mean(reward_buffer)
            print(f'Episode: {len(all_rewards)} Step: {step+1} Average reward: {average_reward}')

    return all_rewards, q_net

# %%
# """ This is baseline """

# # Hyperparameters
# max_epsilon = 1.0
# min_epsilon = 0.01
# max_num_steps = 50000
# epsilon_decay_intervals = 10000
# gamma = 0.99 # discount
# alpha = 5e-4 # learning rate

# memory_size = 50000
# min_replay_size = 1000
# batch_size = 32

# target_update_frequency = 1000 # target network update frequency

# %%
# Hyperparameters
max_epsilon = 1.0
min_epsilon = 0.01
max_num_steps = 100000
epsilon_decay_intervals = 10000
gamma = 0.99 # discount
alpha = 1e-3 # learning rate

memory_size = 100000
min_replay_size = 1000
batch_size = 128

target_update_frequency = 1000 # target network update frequency

# %%
all_rewards, q_net = dqn_training(env, max_num_steps, max_epsilon, min_epsilon, epsilon_decay_intervals, gamma, lr=alpha)
# Out:
# Episode: 5 Step: 1000 Average reward: -200.0
# Episode: 10 Step: 2000 Average reward: -200.0
# Episode: 15 Step: 3000 Average reward: -200.0
# Episode: 20 Step: 4000 Average reward: -200.0
# Episode: 25 Step: 5000 Average reward: -200.0
# Episode: 30 Step: 6000 Average reward: -200.0
# Episode: 35 Step: 7000 Average reward: -200.0
# Episode: 40 Step: 8000 Average reward: -200.0
# Episode: 45 Step: 9000 Average reward: -200.0
# Episode: 50 Step: 10000 Average reward: -200.0
# Episode: 55 Step: 11000 Average reward: -199.96363636363637
# Episode: 60 Step: 12000 Average reward: -199.96666666666667
# Episode: 65 Step: 13000 Average reward: -199.96923076923076
# Episode: 70 Step: 14000 Average reward: -199.97142857142856
# Episode: 75 Step: 15000 Average reward: -199.97333333333333
# Episode: 80 Step: 16000 Average reward: -199.975
# Episode: 85 Step: 17000 Average reward: -199.9764705882353
# Episode: 90 Step: 18000 Average reward: -199.9777777777778
# Episode: 95 Step: 19000 Average reward: -199.97894736842105
# Episode: 100 Step: 20000 Average reward: -199.98
# Episode: 105 Step: 21000 Average reward: -199.98
# Episode: 110 Step: 22000 Average reward: -199.98
# Episode: 115 Step: 23000 Average reward: -199.98
# Episode: 120 Step: 24000 Average reward: -199.98
# Episode: 125 Step: 25000 Average reward: -199.98
# Episode: 130 Step: 26000 Average reward: -199.98
# Episode: 135 Step: 27000 Average reward: -199.98
# Episode: 140 Step: 28000 Average reward: -199.98
# Episode: 145 Step: 29000 Average reward: -199.98
# Episode: 150 Step: 30000 Average reward: -199.98
# Episode: 155 Step: 31000 Average reward: -200.0
# Episode: 160 Step: 32000 Average reward: -200.0
# Episode: 165 Step: 33000 Average reward: -200.0
# Episode: 170 Step: 34000 Average reward: -200.0
# Episode: 175 Step: 35000 Average reward: -200.0
# Episode: 180 Step: 36000 Average reward: -199.28
# Episode: 185 Step: 37000 Average reward: -198.4
# Episode: 190 Step: 38000 Average reward: -198.4
# Episode: 195 Step: 39000 Average reward: -198.4
# Episode: 201 Step: 40000 Average reward: -197.87
# Episode: 206 Step: 41000 Average reward: -197.87
# Episode: 211 Step: 42000 Average reward: -197.87
# Episode: 216 Step: 43000 Average reward: -197.85
# Episode: 221 Step: 44000 Average reward: -197.85
# Episode: 226 Step: 45000 Average reward: -197.38
# Episode: 231 Step: 46000 Average reward: -196.9
# Episode: 237 Step: 47000 Average reward: -195.93
# Episode: 242 Step: 48000 Average reward: -195.34
# Episode: 247 Step: 49000 Average reward: -195.1
# Episode: 252 Step: 50000 Average reward: -194.45
# Episode: 258 Step: 51000 Average reward: -193.39
# Episode: 263 Step: 52000 Average reward: -192.44
# Episode: 269 Step: 53000 Average reward: -191.32
# Episode: 275 Step: 54000 Average reward: -189.28
# Episode: 281 Step: 55000 Average reward: -188.14
# Episode: 287 Step: 56000 Average reward: -187.34
# Episode: 292 Step: 57000 Average reward: -186.43
# Episode: 298 Step: 58000 Average reward: -185.32
# Episode: 303 Step: 59000 Average reward: -184.34
# Episode: 309 Step: 60000 Average reward: -183.58
# Episode: 314 Step: 61000 Average reward: -182.68
# Episode: 320 Step: 62000 Average reward: -181.44
# Episode: 326 Step: 63000 Average reward: -180.32
# Episode: 331 Step: 64000 Average reward: -179.53
# Episode: 337 Step: 65000 Average reward: -180.03
# Episode: 342 Step: 66000 Average reward: -180.11
# Episode: 347 Step: 67000 Average reward: -179.48
# Episode: 352 Step: 68000 Average reward: -179.93
# Episode: 358 Step: 69000 Average reward: -178.96
# Episode: 364 Step: 70000 Average reward: -179.25
# Episode: 370 Step: 71000 Average reward: -179.22
# Episode: 375 Step: 72000 Average reward: -180.15
# Episode: 380 Step: 73000 Average reward: -181.08
# Episode: 385 Step: 74000 Average reward: -182.81
# Episode: 391 Step: 75000 Average reward: -182.97
# Episode: 396 Step: 76000 Average reward: -183.67
# Episode: 402 Step: 77000 Average reward: -183.23
# Episode: 407 Step: 78000 Average reward: -182.92
# Episode: 413 Step: 79000 Average reward: -182.06
# Episode: 419 Step: 80000 Average reward: -181.98
# Episode: 425 Step: 81000 Average reward: -181.63
# Episode: 430 Step: 82000 Average reward: -182.26
# Episode: 436 Step: 83000 Average reward: -180.92
# Episode: 442 Step: 84000 Average reward: -179.49
# Episode: 448 Step: 85000 Average reward: -178.97
# Episode: 454 Step: 86000 Average reward: -176.62
# Episode: 460 Step: 87000 Average reward: -176.38
# Episode: 467 Step: 88000 Average reward: -174.78
# Episode: 473 Step: 89000 Average reward: -173.19
# Episode: 479 Step: 90000 Average reward: -171.55
# Episode: 486 Step: 91000 Average reward: -168.98
# Episode: 493 Step: 92000 Average reward: -165.43
# Episode: 499 Step: 93000 Average reward: -165.04
# Episode: 506 Step: 94000 Average reward: -162.14
# Episode: 512 Step: 95000 Average reward: -161.67
# Episode: 518 Step: 96000 Average reward: -161.75
# Episode: 525 Step: 97000 Average reward: -160.2
# Episode: 531 Step: 98000 Average reward: -158.89
# Episode: 538 Step: 99000 Average reward: -157.4
# Episode: 544 Step: 100000 Average reward: -156.75

# %%
all_rewards = np.array(all_rewards)
plt.xlabel('Steps')
plt.ylabel('Score')
plt.plot(all_rewards[:, 0], all_rewards[:, 1])

# %%
env = Recorder(env, './video')
state = env.reset()
done = False
total_reward = 0.0
q_net.eval()

with torch.no_grad():
    while not done:
        #action = env.action_space.sample()
        action = q_net.choose_action(state)
        next_state, reward, done, info = env.step(action)
        total_reward += reward
        state = next_state

print(total_reward)
env.play()
# Out:
# -150.0
# 100%|██████████| 151/151 [00:00<00:00, 276.19it/s]
# <div align=middle><video width='400' height='600'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
